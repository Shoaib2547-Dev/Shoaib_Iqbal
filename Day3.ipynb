# %% [markdown]
# **Load Data**

# %%
import pandas as pd

Df_T=pd.read_csv("/content/Titanic-Dataset.csv")
Df_T
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Question#1:**  Shows the male whose age is less than 22

# %%
Df_T[(Df_T["Age"]<22) & (Df_T["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 16            17         0       3                     Rice, Master. Eugene
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 37            38         0       3                 Cann, Mr. Ernest Charles
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 861          862         0       2              Giles, Mr. Frederick Edward
# 869          870         1       3          Johnson, Master. Harold Theodor
# 876          877         0       3            Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                     Petroff, Mr. Nedelio
#
# ...

# %% [markdown]
# **Question#2:** Create another column for Expensive and cheap Fare

# %%
import numpy as np
# It create the array
np.where(Df_T["Fare"]>200 ,"Expensive","Cheap")
#  Create New Column
Df_T["Price_Checker"]=np.where(Df_T["Fare"]>200 ,"Expensive","Cheap")
Df_T
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Question#3:** Find all passengers who survived.

# %%
Df_T[Df_T["Survived"]==1]
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age   SibSp  Parch  Ticket    Fare     Cabin  Embarked  Price_Checker
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1      0      PC 17599  71.2833  C85    C         Cheap            1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1      0      113803    53.1000  C123   S         Cheap            1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0   1      1      PP 9549   16.7000  G6     S         Cheap            1
# 12           1         1       Bonnell, Miss. Elizabeth                             female  58.0  0      0      113783    26.5500  C103   S         Cheap            1
# ...

# %% [markdown]
# **Question#4:** Find the passenger who paid the highest fare.

# %%
Df_T.sort_values("Fare",ascending=False).head(1)
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
#
#     Price_Checker
# 679     Expensive

# %% [markdown]
# . **Question#5**Find the number of survivors and non-survivors in each class.

# %%
Df_T.groupby(["Pclass","Survived"]).size()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %% [markdown]
# **Question#6:**Find the Average fare by passenger class

# %%
Df_T.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# **Question#7:** what is the age of Braund, Mr. Owen Harris and check it is male

# %%
Df_T[(Df_T["Name"]=="Braund, Mr. Owen Harris") & (Df_T['Sex']=="male")]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked Price_Checker
# 0      0  A/5 21171  7.25   NaN        S         Cheap

# %% [markdown]
# **QUestion#8:**Find all female passengers who survived.

# %%
Df_T[(Df_T['Sex']=="female")&(Df_T["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...
